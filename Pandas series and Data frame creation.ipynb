# %%
import pandas as pd
d={'g':456,'s':143,'f':678}
result=pd.Series(d)
result
# Out:
# g    456
# s    143
# f    678
# dtype: int64

# %%
import pandas as pd
d=(12,3,45,78,36)
result=pd.Series(d)
result
# Out:
# 0    12
# 1     3
# 2    45
# 3    78
# 4    36
# dtype: int64

# %%
import pandas as pd
d=[34,67,89,91,1,32]
result=pd.Series(d)
result
# Out:
# 0    34
# 1    67
# 2    89
# 3    91
# 4     1
# 5    32
# dtype: int64

# %%
import random
input=[]
for i in range(1,10):
  y=random.randrange(10,20)
  input.append(y)
result=pd.Series(input)
result
# Out:
# 0    17
# 1    14
# 2    11
# 3    13
# 4    14
# 5    13
# 6    15
# 7    12
# 8    14
# dtype: int64

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
a= {
    'Name' : ['Ankit', 'Aishwarya', 'Shaurya', 'Shivangi'],
    'Age' : [23, 21, 22, 21],
    'University' : ['BHU', 'JNU', 'DU', 'BHU'],}
result=pd.DataFrame(a)
result
# Out:
#         Name  Age University
# 0      Ankit   23        BHU
# 1  Aishwarya   21        JNU
# 2    Shaurya   22         DU
# 3   Shivangi   21        BHU

# %%
df=pd.read_excel('/content/titanic 1.xlsx')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df=pd.read_csv('/content/titanic 1 (1).csv')
df
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
ser1=pd.DataFrame(data=df['ticket'])
ser1
# Out:
#       ticket
# 0      24160
# 1     113781
# 2     113781
# 3     113781
# 4     113781
# ...      ...
# 1304    2665
# 1305    2665
# 1306    2656
# 1307    2670
# 1308  315082
#
# [1309 rows x 1 columns]

# %%
d= df.drop(df[df.ticket==3000].index)
d
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
s = pd.Series(["8", 6, "7.5", 3, "0.9"])
s
# Out:
# 0      8
# 1      6
# 2    7.5
# 3      3
# 4    0.9
# dtype: object

# %%
pd.to_numeric(s)
# Out:
# 0    8.0
# 1    6.0
# 2    7.5
# 3    3.0
# 4    0.9
# dtype: float64

# %%
df=pd.DataFrame(df,columns=['age','fare'])
df
# Out:
#           age      fare
# 0     29.0000  211.3375
# 1      0.9167  151.5500
# 2      2.0000  151.5500
# 3     30.0000  151.5500
# 4     25.0000  151.5500
# ...       ...       ...
# 1304  14.5000   14.4542
# 1305      NaN   14.4542
# 1306  26.5000    7.2250
# 1307  27.0000    7.2250
# 1308  29.0000    7.8750
#
# [1309 rows x 2 columns]
